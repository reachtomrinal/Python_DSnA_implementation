# %% [markdown]
# <a href="https://colab.research.google.com/github/reachtomrinal/python_DSnA_Implementation/blob/main/Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New section
